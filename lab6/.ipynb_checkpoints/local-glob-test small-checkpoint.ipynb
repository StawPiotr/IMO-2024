# %% [markdown]
# # IMO - Zadanie 6
#
# Autorzy: Alex Terentowicz, Piotr Stawski
# ---

# %% [markdown]
# Imports:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import itertools
import time
import multiprocessing as mp
from copy import deepcopy
plt.rc('figure', dpi=110, figsize=(9, 5))

# %% [markdown]
# Reading instance functions:

# %%
def distance(a, b):
    return np.round(np.sqrt(np.sum((a - b)**2)))

def read_instance(path):
    coords = pd.read_csv(path, sep=' ', names=['n','x','y'], skiprows=6, skipfooter=1, engine='python')
    cities = coords.drop(columns=['n']).values
    ns = np.arange(len(cities))
    cities = np.array([[distance(cities[i], cities[j]) for j in ns] for i in ns])
    return cities, coords

# %% [markdown]
# Drawing functions:

# %%
def draw_path(coords, path, color='blue'):
    cycle = path + [path[0]]
    for i in range(len(cycle) - 1):
        a, b = cycle[i], cycle[i+1]
        plt.plot([coords.x[a], coords.x[b]], [coords.y[a], coords.y[b]], color=color)

def plot_solution(coords, solution):
    path1, path2 = solution
    draw_path(coords, path1, color='blue')
    draw_path(coords, path2, color='red')
    plt.scatter(coords.x, coords.y, color='grey')
    plt.show()

# %% [markdown]
# Scoring functions:

# %%
def cycle_score(cities, path):
    cycle = path + [path[0]]
    return sum(cities[cycle[i], cycle[i+1]] for i in range(len(cycle) - 1))

def score(cities, paths):
    return cycle_score(cities, paths[0]) + cycle_score(cities, paths[1])

def delta_insert(cities, path, i, city):
    a, b = path[i - 1], path[i]
    return cities[a, city] + cities[city, b] - cities[a, b]

# %% [markdown]
# Generating pairs of path indices for local search:

# %% [markdown]
# Replacing elements for local search (two cycles and one cycle):

# %%
# Score difference after replacing element "i" of path with chosen city
def delta_replace_vertex(cities, path, i, city):
    path_len = len(path)
    a, b, c = path[(i - 1)%path_len], path[i], path[(i+1)%path_len]
    return cities[a, city] + cities[city, c] - cities[a, b] - cities[b, c]

# Score difference after exchanging 2 vertices of 2 different paths on indices i and j
def delta_replace_vertices_outside(cities, paths, i, j):
    return delta_replace_vertex(cities, paths[0], i, paths[1][j]) + delta_replace_vertex(cities, paths[1], j, paths[0][i])

# Score difference after exchanging 2 vertices of the same path on indices i and j
def delta_replace_vertices_inside(cities, path, i, j):
    path_len = len(path)
    a, b, c = path[(i - 1)%path_len], path[i], path[(i+1)%path_len]
    d, e, f = path[(j-1)%path_len], path[j], path[(j+1)%path_len]
    if j-i == 1:
        return cities[a,e]+cities[b,f]-cities[a,b]-cities[e,f]
    elif (i, j) == (0, len(path)-1):
        return cities[e, c] + cities[d, b] - cities[b, c] - cities[d, e]
    else:
        return cities[a,e] + cities[e,c] + cities[d,b] + cities[b,f] -cities[a,b]-cities[b,c]-cities[d,e] - cities[e,f] 

# Score difference after exchanging 2 elements of the same path on edges between i and j
def delta_replace_edges_inside(cities, path, i, j):
    path_len = len(path)
    if (i, j) == (0, len(path)-1):
        a, b, c, d = path[i], path[(i+1)%path_len], path[(j-1)%path_len], path[j]
    else:
        a, b, c, d = path[(i - 1)%path_len], path[i], path[j], path[(j+1)%path_len]
    return cities[a, c] + cities[b, d] - cities[a, b] - cities[c, d]

# generates indices for testing every pair of two paths
def outside_candidates(paths):
    indices = list(range(len(paths[0]))), list(range(len(paths[1])))
    indices_pairwise = list(itertools.product(*indices))
    return indices_pairwise

# generates combinations of all pairs of one path
def inside_candidates(path):
    combinations = []
    for i in range(len(path)):
        for j in range(i+1, len(path)):
            combinations.append([i, j])
    return combinations

def replace_vertices_outside(paths, i, j):
    temp = paths[0][i]
    paths[0][i] = paths[1][j]
    paths[1][j] = temp

def replace_vertices_inside(path, i, j):
    temp = path[i]
    path[i] = path[j]
    path[j] = temp
    
def replace_edges_inside(path, i, j):
    if (i, j) == (0, len(path)-1):
        temp = path[i]
        path[i] = path[j]
        path[j] = temp     
    path[i:j+1] = reversed(path[i:j+1])
    
class SteepestSearch(object):
    def __init__(self, cities, variant):
        self.variant = variant
        if variant == "vertices":
            self.delta = delta_replace_vertices_inside
            self.replace = replace_vertices_inside
        else:
            self.delta = delta_replace_edges_inside
            self.replace = replace_edges_inside
        self.cities = cities
        self.moves = [self.outside_vertices_trade_best, self.inside_trade_best]
    
    def outside_vertices_trade_best(self, cities, paths):
        candidates = outside_candidates(paths)
        scores = np.array([delta_replace_vertices_outside(cities, paths, i, j) for i, j in candidates])
        best_result_idx = np.argmin(scores)
        if scores[best_result_idx] < 0:
            return replace_vertices_outside, (paths, *candidates[best_result_idx]), scores[best_result_idx]
        return _, _, scores[best_result_idx]
            
    def inside_trade_best(self, cities, paths):
        combinations = inside_candidates(paths[0]), inside_candidates(paths[1])
        scores = np.array([[self.delta(cities, paths[idx], i, j) for i, j in combinations[idx]] for idx in range(len(paths))])
        best_path_idx, best_combination = np.unravel_index(np.argmin(scores), scores.shape)
        best_score = scores[best_path_idx, best_combination]
        if best_score < 0:
            return self.replace, (paths[best_path_idx], *combinations[best_path_idx][best_combination]), best_score
        return _, _, best_score 
    
    def __call__(self, paths):
        paths = deepcopy(paths)
        start = time.time()
        while True:
            replace_funs, args, scores = list(zip(*[move(self.cities, paths) for move in self.moves]))
            best_score_idx = np.argmin(scores)
            if scores[best_score_idx] < 0:
                replace_funs[best_score_idx](*args[best_score_idx])
            else:
                break
        return time.time()-start, paths

# %% [markdown]
# Initial solvers:

# %%
def solve_random(args):
    cities, _ = args
    n = cities.shape[0]
    remaining = list(range(n))
    random.seed()
    random.shuffle(remaining)
    paths = [remaining[:n//2], remaining[n//2:]]
    return paths

# %% [markdown]
# Greedy (first improvement) local search algorithm:

# %%
class GreedySearch(object):
    def __init__(self, cities, variant):
        self.variant = variant
        if variant == "vertices":
            self.delta = delta_replace_vertices_inside
            self.replace = replace_vertices_inside
        else:
            self.delta = delta_replace_edges_inside
            self.replace = replace_edges_inside
        self.cities = cities
        self.moves = [self.outside_vertices_trade_first, self.inside_trade_first]
    
    def outside_vertices_trade_first(self, cities, paths):
        random.seed()
        candidates = outside_candidates(paths)
        random.shuffle(candidates)
        for i, j in candidates:
            score_diff = delta_replace_vertices_outside(cities, paths, i, j)
            if score_diff < 0:
                replace_vertices_outside(paths, i, j)
                return score_diff
        return score_diff

    def inside_trade_first(self, cities, paths):
        random.seed()
        path_order = random.sample(range(2), 2)
        for idx in path_order:
            candidates = inside_candidates(paths[idx])
            random.shuffle(candidates)
            for i, j in candidates:
                score_diff = self.delta(cities, paths[idx], i, j)
                if score_diff < 0:
                    self.replace(paths[idx], i, j)
                    return score_diff
        return score_diff 
    
    def __call__(self, paths):
        paths = deepcopy(paths)
        random.seed()
        start = time.time()
        while True:
            move_order = random.sample(range(2), 2)
            score = self.moves[move_order[0]](self.cities, paths)
            if score >= 0: 
                score = self.moves[move_order[1]](self.cities, paths)
                if score >= 0: 
                    break
        return time.time()-start, paths

# %%
def check_edge(ver1, ver2, cycle):
    for i in range(0, len(cycle)-1):
        if cycle[i]==ver1:
            if cycle[i+1]==ver2:
#                 print(ver1, ver2, cycle)
                return 1
        if cycle[i]==ver2:
            if cycle[i+1]==ver1:
#                 print(ver2, ver1, cycle)
                return 1
    if cycle[-1]==ver1:
        if cycle[0]==ver2:
            return 1
    if cycle[-1]==ver2:
        if cycle[0]==ver1:
            return 1 
    return 0
    

def count_vertex(list1, list2):
    count = 0
    for i in range(0, len(list1)):
        for j in range(0, len(list2)):
            if list1[i] == list2[j]:
                count += 1
                break
    return count
  
    
def count_first_score(opt,best):
    sum1 = count_vertex(opt[0], best[0]) + count_vertex(opt[1], best[1])
    sum2 = count_vertex(opt[0], best[1]) + count_vertex(opt[1], best[0])
    return max(sum1,sum2)

def count_second_score(list1, list2):
    count = 0
    for i in range(len(list1[0]) - 1):
        count += check_edge(list1[0][i], list1[0][i+1], list2[0])
        count += check_edge(list1[0][i], list1[0][i+1], list2[1])
        count += check_edge(list2[0][i], list2[0][i+1], list2[0])
        count += check_edge(list2[0][i], list2[0][i+1], list2[1])

        
    count += check_edge(list1[0][-1], list1[0][0], list2[0])
    count += check_edge(list1[0][-1], list1[0][0], list2[1])
    count += check_edge(list1[1][-1], list1[1][0], list2[0])
    count += check_edge(list1[1][-1], list1[1][0], list2[1])
        
    return count

# %%
def show_results1000():
    instances = ['kroB200.tsp']
    initial_solvers = [solve_random]
    score_results = []
    time_results = []
    best_score_arr = []
    first_scores_arr = []
    second_scores_arr = []
    avg_first_scores_arr = []
    avg_second_scores_arr = []
    all_solutions = []
    all_scores = []
    best_score = 100000000000000
    for file in instances:
        cities, coords = read_instance(file)
        local_variants = [GreedySearch(cities, "edges")]
        for solve in initial_solvers:
            times, new_solutions = [], []
            for i in range(1000):
                new_solutions = []
                for local_search in local_variants:
                    solution = solve((cities, i))
                    print(file, i)
                    time, new_solution = local_search(solution)
                    times.append(time)
                    new_solutions.append(new_solution)
                    all_solutions.append(new_solution)                   
                    new_scores = [score(cities, x) for x in new_solutions]
                    all_scores.append(new_scores[0])
                    for i in range(0, len(new_scores)):
                        if new_scores[i] < best_score:
                            best_score = new_scores[i]
                            best_idx = i
                            best = new_solutions[i]
    print("start measure")
    first_scores = []
    second_scores = []
    avg_first_scores = []
    avg_second_scores = []
    for i in range(len(all_solutions)):
        if(all_solutions[i]==best): 
            continue
        first_avg = 0
        second_avg = 0
#         print("COUNT AVG")
        for opt_for_avg in all_solutions:
            if(all_solutions[i]==opt_for_avg): continue
            first_avg += count_first_score(opt_for_avg,best)
            second_avg += count_second_score(opt_for_avg,best)
#             print(first_avg, second_avg)
#         print(first_avg, float(len(all_solutions)-1), first_avg/float(len(all_solutions)-1))
#         print(second_avg, float(len(all_solutions)-1), second_avg/float(len(all_solutions)-1))
        avg_first_scores_arr.append(first_avg/float(len(all_solutions)-1))
        avg_second_scores_arr.append(second_avg/float(len(all_solutions)-1))
        best_score_arr.append(all_scores[i])
        first_scores_arr.append(count_first_score(all_solutions[i],best))
        second_scores_arr.append(count_second_score(all_solutions[i],best))
#         avg_first_scores_arr.append(max(avg_first_scores))
#         avg_second_scores_arr.append(max(avg_second_scores))
                    
    return best_score, best_score_arr, first_scores_arr, second_scores_arr, avg_first_scores_arr, avg_second_scores_arr

# %%
best_score_arr = []
first_scores_arr = []
second_scores_arr = []
avg_first_scores_arr = []
avg_second_scores_arr = []
best_score, best_score_arr, first_scores_arr, second_scores_arr, avg_first_scores_arr, avg_second_scores_arr = show_results1000()
print(best_score)
# print(best_score_arr)
# print(first_scores_arr)
# print(second_scores_arr)
# print(avg_first_scores_arr)
# print(avg_second_scores_arr)
# Out:
# kroB200.tsp 0
# kroB200.tsp 1
# kroB200.tsp 2
# kroB200.tsp 3
# kroB200.tsp 4
# kroB200.tsp 5
# kroB200.tsp 6
# kroB200.tsp 7
# kroB200.tsp 8
# kroB200.tsp 9
# kroB200.tsp 10
# kroB200.tsp 11
# kroB200.tsp 12
# kroB200.tsp 13
# kroB200.tsp 14
# kroB200.tsp 15
# kroB200.tsp 16
# kroB200.tsp 17
# kroB200.tsp 18
# kroB200.tsp 19
# kroB200.tsp 20
# kroB200.tsp 21
# kroB200.tsp 22
# kroB200.tsp 23
# kroB200.tsp 24
# kroB200.tsp 25
# kroB200.tsp 26
# kroB200.tsp 27
# kroB200.tsp 28
# kroB200.tsp 29
# kroB200.tsp 30
# kroB200.tsp 31
# kroB200.tsp 32
# kroB200.tsp 33
# kroB200.tsp 34
# kroB200.tsp 35
# kroB200.tsp 36
# kroB200.tsp 37
# kroB200.tsp 38
# kroB200.tsp 39
# kroB200.tsp 40
# kroB200.tsp 41
# kroB200.tsp 42
# kroB200.tsp 43
# kroB200.tsp 44
# kroB200.tsp 45
# kroB200.tsp 46
# kroB200.tsp 47
# kroB200.tsp 48
# kroB200.tsp 49
# kroB200.tsp 50
# kroB200.tsp 51
# kroB200.tsp 52
# kroB200.tsp 53
# kroB200.tsp 54
# kroB200.tsp 55
# kroB200.tsp 56
# kroB200.tsp 57
# kroB200.tsp 58
# kroB200.tsp 59
# kroB200.tsp 60
# kroB200.tsp 61
# kroB200.tsp 62
# kroB200.tsp 63
# kroB200.tsp 64
# kroB200.tsp 65
# kroB200.tsp 66
# kroB200.tsp 67
# kroB200.tsp 68
# kroB200.tsp 69
# kroB200.tsp 70
# kroB200.tsp 71
# kroB200.tsp 72
# kroB200.tsp 73
# kroB200.tsp 74
# kroB200.tsp 75
# kroB200.tsp 76
# kroB200.tsp 77
# kroB200.tsp 78
# kroB200.tsp 79
# kroB200.tsp 80
# kroB200.tsp 81
# kroB200.tsp 82
# kroB200.tsp 83
# kroB200.tsp 84
# kroB200.tsp 85
# kroB200.tsp 86
# kroB200.tsp 87
# kroB200.tsp 88
# kroB200.tsp 89
# kroB200.tsp 90
# kroB200.tsp 91
# kroB200.tsp 92
# kroB200.tsp 93
# kroB200.tsp 94
# kroB200.tsp 95
# kroB200.tsp 96
# kroB200.tsp 97
# kroB200.tsp 98
# kroB200.tsp 99
# kroB200.tsp 100
# kroB200.tsp 101
# kroB200.tsp 102
# kroB200.tsp 103
# kroB200.tsp 104
# kroB200.tsp 105
# kroB200.tsp 106
# kroB200.tsp 107
# kroB200.tsp 108
# kroB200.tsp 109
# kroB200.tsp 110
# kroB200.tsp 111
# kroB200.tsp 112
# kroB200.tsp 113
# kroB200.tsp 114
# kroB200.tsp 115
# kroB200.tsp 116
# kroB200.tsp 117
# kroB200.tsp 118
# kroB200.tsp 119
# kroB200.tsp 120
# kroB200.tsp 121
# kroB200.tsp 122
# kroB200.tsp 123
# kroB200.tsp 124
# kroB200.tsp 125
# kroB200.tsp 126
# kroB200.tsp 127
# kroB200.tsp 128
# kroB200.tsp 129
# kroB200.tsp 130
# kroB200.tsp 131
# kroB200.tsp 132
# kroB200.tsp 133
# kroB200.tsp 134
# kroB200.tsp 135
# kroB200.tsp 136
# kroB200.tsp 137
# kroB200.tsp 138
# kroB200.tsp 139
# kroB200.tsp 140
# kroB200.tsp 141
# kroB200.tsp 142
# kroB200.tsp 143
# kroB200.tsp 144
# kroB200.tsp 145
# kroB200.tsp 146
# kroB200.tsp 147
# kroB200.tsp 148
# kroB200.tsp 149
# kroB200.tsp 150
# kroB200.tsp 151
# kroB200.tsp 152
# kroB200.tsp 153
# kroB200.tsp 154
# kroB200.tsp 155
# kroB200.tsp 156
# kroB200.tsp 157
# kroB200.tsp 158
# kroB200.tsp 159
# kroB200.tsp 160
# kroB200.tsp 161
# kroB200.tsp 162
# kroB200.tsp 163
# kroB200.tsp 164
# kroB200.tsp 165
# kroB200.tsp 166
# kroB200.tsp 167
# kroB200.tsp 168
# kroB200.tsp 169
# kroB200.tsp 170
# kroB200.tsp 171
# kroB200.tsp 172
# kroB200.tsp 173
# kroB200.tsp 174
# kroB200.tsp 175
# kroB200.tsp 176
# kroB200.tsp 177
# kroB200.tsp 178
# kroB200.tsp 179
# kroB200.tsp 180
# kroB200.tsp 181
# kroB200.tsp 182
# kroB200.tsp 183
# kroB200.tsp 184
# kroB200.tsp 185
# kroB200.tsp 186
# kroB200.tsp 187
# kroB200.tsp 188
# kroB200.tsp 189
# kroB200.tsp 190
# kroB200.tsp 191
# kroB200.tsp 192
# kroB200.tsp 193
# kroB200.tsp 194
# kroB200.tsp 195
# kroB200.tsp 196
# kroB200.tsp 197
# kroB200.tsp 198
# kroB200.tsp 199
# kroB200.tsp 200
# kroB200.tsp 201
# kroB200.tsp 202
# kroB200.tsp 203
# kroB200.tsp 204
# kroB200.tsp 205
# kroB200.tsp 206
# kroB200.tsp 207
# kroB200.tsp 208
# kroB200.tsp 209
# kroB200.tsp 210
# kroB200.tsp 211
# kroB200.tsp 212
# kroB200.tsp 213
# kroB200.tsp 214
# kroB200.tsp 215
# kroB200.tsp 216
# kroB200.tsp 217
# kroB200.tsp 218
# kroB200.tsp 219
# kroB200.tsp 220
# kroB200.tsp 221
# kroB200.tsp 222
# kroB200.tsp 223
# kroB200.tsp 224
# kroB200.tsp 225
# kroB200.tsp 226
# kroB200.tsp 227
# kroB200.tsp 228
# kroB200.tsp 229
# kroB200.tsp 230
# kroB200.tsp 231
# kroB200.tsp 232
# kroB200.tsp 233
# kroB200.tsp 234
# kroB200.tsp 235
# kroB200.tsp 236
# kroB200.tsp 237
# kroB200.tsp 238
# kroB200.tsp 239
# kroB200.tsp 240
# kroB200.tsp 241
# kroB200.tsp 242
# kroB200.tsp 243
# kroB200.tsp 244
# kroB200.tsp 245
# kroB200.tsp 246
# kroB200.tsp 247
# kroB200.tsp 248
# kroB200.tsp 249
# kroB200.tsp 250
# kroB200.tsp 251
# kroB200.tsp 252
# kroB200.tsp 253
# kroB200.tsp 254
# kroB200.tsp 255
# kroB200.tsp 256
# kroB200.tsp 257
# kroB200.tsp 258
# kroB200.tsp 259
# kroB200.tsp 260
# kroB200.tsp 261
# kroB200.tsp 262
# kroB200.tsp 263
# kroB200.tsp 264
# kroB200.tsp 265
# kroB200.tsp 266
# kroB200.tsp 267
# kroB200.tsp 268
# kroB200.tsp 269
# kroB200.tsp 270
# kroB200.tsp 271
# kroB200.tsp 272
# kroB200.tsp 273
# kroB200.tsp 274
# kroB200.tsp 275
# kroB200.tsp 276
# kroB200.tsp 277
# kroB200.tsp 278
# kroB200.tsp 279
# kroB200.tsp 280
# kroB200.tsp 281
# kroB200.tsp 282
# kroB200.tsp 283
# kroB200.tsp 284
# kroB200.tsp 285
# kroB200.tsp 286
# kroB200.tsp 287
# kroB200.tsp 288
# kroB200.tsp 289
# kroB200.tsp 290
# kroB200.tsp 291
# kroB200.tsp 292
# kroB200.tsp 293
# kroB200.tsp 294
# kroB200.tsp 295
# kroB200.tsp 296
# kroB200.tsp 297
# kroB200.tsp 298
# kroB200.tsp 299
# kroB200.tsp 300
# kroB200.tsp 301
# kroB200.tsp 302
# kroB200.tsp 303
# kroB200.tsp 304
# kroB200.tsp 305
# kroB200.tsp 306
# kroB200.tsp 307
# kroB200.tsp 308
# kroB200.tsp 309
# kroB200.tsp 310
# kroB200.tsp 311
# kroB200.tsp 312
# kroB200.tsp 313
# kroB200.tsp 314
# kroB200.tsp 315
# kroB200.tsp 316
# kroB200.tsp 317
# kroB200.tsp 318
# kroB200.tsp 319
# kroB200.tsp 320
# kroB200.tsp 321
# kroB200.tsp 322
# kroB200.tsp 323
# kroB200.tsp 324
# kroB200.tsp 325
# kroB200.tsp 326
# kroB200.tsp 327
# kroB200.tsp 328
# kroB200.tsp 329
# kroB200.tsp 330
# kroB200.tsp 331
# kroB200.tsp 332
# kroB200.tsp 333
# kroB200.tsp 334
# kroB200.tsp 335
# kroB200.tsp 336
# kroB200.tsp 337
# kroB200.tsp 338
# kroB200.tsp 339
# kroB200.tsp 340
# kroB200.tsp 341
# kroB200.tsp 342
# kroB200.tsp 343
# kroB200.tsp 344
# kroB200.tsp 345
# kroB200.tsp 346
# kroB200.tsp 347
# kroB200.tsp 348
# kroB200.tsp 349
# kroB200.tsp 350
# kroB200.tsp 351
# kroB200.tsp 352
# kroB200.tsp 353
# kroB200.tsp 354
# kroB200.tsp 355
# kroB200.tsp 356
# kroB200.tsp 357
# kroB200.tsp 358
# kroB200.tsp 359
# kroB200.tsp 360
# kroB200.tsp 361
# kroB200.tsp 362
# kroB200.tsp 363
# kroB200.tsp 364
# kroB200.tsp 365
# kroB200.tsp 366
# kroB200.tsp 367
# kroB200.tsp 368
# kroB200.tsp 369
# kroB200.tsp 370
# kroB200.tsp 371
# kroB200.tsp 372
# kroB200.tsp 373
# kroB200.tsp 374
# kroB200.tsp 375
# kroB200.tsp 376
# kroB200.tsp 377
# kroB200.tsp 378
# kroB200.tsp 379
# kroB200.tsp 380
# kroB200.tsp 381
# kroB200.tsp 382
# kroB200.tsp 383
# kroB200.tsp 384
# kroB200.tsp 385
# kroB200.tsp 386
# kroB200.tsp 387
# kroB200.tsp 388
# kroB200.tsp 389
# kroB200.tsp 390
# kroB200.tsp 391
# kroB200.tsp 392
# kroB200.tsp 393
# kroB200.tsp 394
# kroB200.tsp 395
# kroB200.tsp 396
# kroB200.tsp 397
# kroB200.tsp 398
# kroB200.tsp 399
# kroB200.tsp 400
# kroB200.tsp 401
# kroB200.tsp 402
# kroB200.tsp 403
# kroB200.tsp 404
# kroB200.tsp 405
# kroB200.tsp 406
# kroB200.tsp 407
# kroB200.tsp 408
# kroB200.tsp 409
# kroB200.tsp 410
# kroB200.tsp 411
# kroB200.tsp 412
# kroB200.tsp 413
# kroB200.tsp 414
# kroB200.tsp 415
# kroB200.tsp 416
# kroB200.tsp 417
# kroB200.tsp 418
# kroB200.tsp 419
# kroB200.tsp 420
# kroB200.tsp 421
# kroB200.tsp 422
# kroB200.tsp 423
# kroB200.tsp 424
# kroB200.tsp 425
# kroB200.tsp 426
# kroB200.tsp 427
# kroB200.tsp 428
# kroB200.tsp 429
# kroB200.tsp 430
# kroB200.tsp 431
# kroB200.tsp 432
# kroB200.tsp 433
# kroB200.tsp 434
# kroB200.tsp 435
# kroB200.tsp 436
# kroB200.tsp 437
# kroB200.tsp 438
# kroB200.tsp 439
# kroB200.tsp 440
# kroB200.tsp 441
# kroB200.tsp 442
# kroB200.tsp 443
# kroB200.tsp 444
# kroB200.tsp 445
# kroB200.tsp 446
# kroB200.tsp 447
# kroB200.tsp 448
# kroB200.tsp 449
# kroB200.tsp 450
# kroB200.tsp 451
# kroB200.tsp 452
# kroB200.tsp 453
# kroB200.tsp 454
# kroB200.tsp 455
# kroB200.tsp 456
# kroB200.tsp 457
# kroB200.tsp 458
# kroB200.tsp 459
# kroB200.tsp 460
# kroB200.tsp 461
# kroB200.tsp 462
# kroB200.tsp 463
# kroB200.tsp 464
# kroB200.tsp 465
# kroB200.tsp 466
# kroB200.tsp 467
# kroB200.tsp 468
# kroB200.tsp 469
# kroB200.tsp 470
# kroB200.tsp 471
# kroB200.tsp 472
# kroB200.tsp 473
# kroB200.tsp 474
# kroB200.tsp 475
# kroB200.tsp 476
# kroB200.tsp 477
# kroB200.tsp 478
# kroB200.tsp 479
# kroB200.tsp 480
# kroB200.tsp 481
# kroB200.tsp 482
# kroB200.tsp 483
# kroB200.tsp 484
# kroB200.tsp 485
# kroB200.tsp 486
# kroB200.tsp 487
# kroB200.tsp 488
# kroB200.tsp 489
# kroB200.tsp 490
# kroB200.tsp 491
# kroB200.tsp 492
# kroB200.tsp 493
# kroB200.tsp 494
# kroB200.tsp 495
# kroB200.tsp 496
# kroB200.tsp 497
# kroB200.tsp 498
# kroB200.tsp 499
# kroB200.tsp 500
# kroB200.tsp 501
# kroB200.tsp 502
# kroB200.tsp 503
# kroB200.tsp 504
# kroB200.tsp 505
# kroB200.tsp 506
# kroB200.tsp 507
# kroB200.tsp 508
# kroB200.tsp 509
# kroB200.tsp 510
# kroB200.tsp 511
# kroB200.tsp 512
# kroB200.tsp 513
# kroB200.tsp 514
# kroB200.tsp 515
# kroB200.tsp 516
# kroB200.tsp 517
# kroB200.tsp 518
# kroB200.tsp 519
# kroB200.tsp 520
# kroB200.tsp 521
# kroB200.tsp 522
# kroB200.tsp 523
# kroB200.tsp 524
# kroB200.tsp 525
# kroB200.tsp 526
# kroB200.tsp 527
# kroB200.tsp 528
# kroB200.tsp 529
# kroB200.tsp 530
# kroB200.tsp 531
# kroB200.tsp 532
# kroB200.tsp 533
# kroB200.tsp 534
# kroB200.tsp 535
# kroB200.tsp 536
# kroB200.tsp 537
# kroB200.tsp 538
# kroB200.tsp 539
# kroB200.tsp 540
# kroB200.tsp 541
# kroB200.tsp 542
# kroB200.tsp 543
# kroB200.tsp 544
# kroB200.tsp 545
# kroB200.tsp 546
# kroB200.tsp 547
# kroB200.tsp 548
# kroB200.tsp 549
# kroB200.tsp 550
# kroB200.tsp 551
# kroB200.tsp 552
# kroB200.tsp 553
# kroB200.tsp 554
# kroB200.tsp 555
# kroB200.tsp 556
# kroB200.tsp 557
# kroB200.tsp 558
# kroB200.tsp 559
# kroB200.tsp 560
# kroB200.tsp 561
# kroB200.tsp 562
# kroB200.tsp 563
# kroB200.tsp 564
# kroB200.tsp 565
# kroB200.tsp 566
# kroB200.tsp 567
# kroB200.tsp 568
# kroB200.tsp 569
# kroB200.tsp 570
# kroB200.tsp 571
# kroB200.tsp 572
# kroB200.tsp 573
# kroB200.tsp 574
# kroB200.tsp 575
# kroB200.tsp 576
# kroB200.tsp 577
# kroB200.tsp 578
# kroB200.tsp 579
# kroB200.tsp 580
# kroB200.tsp 581
# kroB200.tsp 582
# kroB200.tsp 583
# kroB200.tsp 584
# kroB200.tsp 585
# kroB200.tsp 586
# kroB200.tsp 587
# kroB200.tsp 588
# kroB200.tsp 589
# kroB200.tsp 590
# kroB200.tsp 591
# kroB200.tsp 592
# kroB200.tsp 593
# kroB200.tsp 594
# kroB200.tsp 595
# kroB200.tsp 596
# kroB200.tsp 597
# kroB200.tsp 598
# kroB200.tsp 599
# kroB200.tsp 600
# kroB200.tsp 601
# kroB200.tsp 602
# kroB200.tsp 603
# kroB200.tsp 604
# kroB200.tsp 605
# kroB200.tsp 606
# kroB200.tsp 607
# kroB200.tsp 608
# kroB200.tsp 609
# kroB200.tsp 610
# kroB200.tsp 611
# kroB200.tsp 612
# kroB200.tsp 613
# kroB200.tsp 614
# kroB200.tsp 615
# kroB200.tsp 616
# kroB200.tsp 617
# kroB200.tsp 618
# kroB200.tsp 619
# kroB200.tsp 620
# kroB200.tsp 621
# kroB200.tsp 622
# kroB200.tsp 623
# kroB200.tsp 624
# kroB200.tsp 625
# kroB200.tsp 626
# kroB200.tsp 627
# kroB200.tsp 628
# kroB200.tsp 629
# kroB200.tsp 630
# kroB200.tsp 631
# kroB200.tsp 632
# kroB200.tsp 633
# kroB200.tsp 634
# kroB200.tsp 635
# kroB200.tsp 636
# kroB200.tsp 637
# kroB200.tsp 638
# kroB200.tsp 639
# kroB200.tsp 640
# kroB200.tsp 641
# kroB200.tsp 642
# kroB200.tsp 643
# kroB200.tsp 644
# kroB200.tsp 645
# kroB200.tsp 646
# kroB200.tsp 647
# kroB200.tsp 648
# kroB200.tsp 649
# kroB200.tsp 650
# kroB200.tsp 651
# kroB200.tsp 652
# kroB200.tsp 653
# kroB200.tsp 654
# kroB200.tsp 655
# kroB200.tsp 656
# kroB200.tsp 657
# kroB200.tsp 658
# kroB200.tsp 659
# kroB200.tsp 660
# kroB200.tsp 661
# kroB200.tsp 662
# kroB200.tsp 663
# kroB200.tsp 664
# kroB200.tsp 665
# kroB200.tsp 666
# kroB200.tsp 667
# kroB200.tsp 668
# kroB200.tsp 669
# kroB200.tsp 670
# kroB200.tsp 671
# kroB200.tsp 672
# kroB200.tsp 673
# kroB200.tsp 674
# kroB200.tsp 675
# kroB200.tsp 676
# kroB200.tsp 677
# kroB200.tsp 678
# kroB200.tsp 679
# kroB200.tsp 680
# kroB200.tsp 681
# kroB200.tsp 682
# kroB200.tsp 683
# kroB200.tsp 684
# kroB200.tsp 685
# kroB200.tsp 686
# kroB200.tsp 687
# kroB200.tsp 688
# kroB200.tsp 689
# kroB200.tsp 690
# kroB200.tsp 691
# kroB200.tsp 692
# kroB200.tsp 693
# kroB200.tsp 694
# kroB200.tsp 695
# kroB200.tsp 696
# kroB200.tsp 697
# kroB200.tsp 698
# kroB200.tsp 699
# kroB200.tsp 700
# kroB200.tsp 701
# kroB200.tsp 702
# kroB200.tsp 703
# kroB200.tsp 704
# kroB200.tsp 705
# kroB200.tsp 706
# kroB200.tsp 707
# kroB200.tsp 708
# kroB200.tsp 709
# kroB200.tsp 710
# kroB200.tsp 711
# kroB200.tsp 712
# kroB200.tsp 713
# kroB200.tsp 714
# kroB200.tsp 715
# kroB200.tsp 716
# kroB200.tsp 717
# kroB200.tsp 718
# kroB200.tsp 719
# kroB200.tsp 720
# kroB200.tsp 721
# kroB200.tsp 722
# kroB200.tsp 723
# kroB200.tsp 724
# kroB200.tsp 725
# kroB200.tsp 726
# kroB200.tsp 727
# kroB200.tsp 728
# kroB200.tsp 729
# kroB200.tsp 730
# kroB200.tsp 731
# kroB200.tsp 732
# kroB200.tsp 733
# kroB200.tsp 734
# kroB200.tsp 735
# kroB200.tsp 736
# kroB200.tsp 737
# kroB200.tsp 738
# kroB200.tsp 739
# kroB200.tsp 740
# kroB200.tsp 741
# kroB200.tsp 742
# kroB200.tsp 743
# kroB200.tsp 744
# kroB200.tsp 745
# kroB200.tsp 746
# kroB200.tsp 747
# kroB200.tsp 748
# kroB200.tsp 749
# kroB200.tsp 750
# kroB200.tsp 751
# kroB200.tsp 752
# kroB200.tsp 753
# kroB200.tsp 754
# kroB200.tsp 755
# kroB200.tsp 756
# kroB200.tsp 757
# kroB200.tsp 758
# kroB200.tsp 759
# kroB200.tsp 760
# kroB200.tsp 761
# kroB200.tsp 762
# kroB200.tsp 763
# kroB200.tsp 764
# kroB200.tsp 765
# kroB200.tsp 766
# kroB200.tsp 767
# kroB200.tsp 768
# kroB200.tsp 769
# kroB200.tsp 770
# kroB200.tsp 771
# kroB200.tsp 772
# kroB200.tsp 773
# kroB200.tsp 774
# kroB200.tsp 775
# kroB200.tsp 776
# kroB200.tsp 777
# kroB200.tsp 778
# kroB200.tsp 779
# kroB200.tsp 780
# kroB200.tsp 781
# kroB200.tsp 782
# kroB200.tsp 783
# kroB200.tsp 784
# kroB200.tsp 785
# kroB200.tsp 786
# kroB200.tsp 787
# kroB200.tsp 788
# kroB200.tsp 789
# kroB200.tsp 790
# kroB200.tsp 791
# kroB200.tsp 792
# kroB200.tsp 793
# kroB200.tsp 794
# kroB200.tsp 795
# kroB200.tsp 796
# kroB200.tsp 797
# kroB200.tsp 798
# kroB200.tsp 799
# kroB200.tsp 800
# kroB200.tsp 801
# kroB200.tsp 802
# kroB200.tsp 803
# kroB200.tsp 804
# kroB200.tsp 805
# kroB200.tsp 806
# kroB200.tsp 807
# kroB200.tsp 808
# kroB200.tsp 809
# kroB200.tsp 810
# kroB200.tsp 811
# kroB200.tsp 812
# kroB200.tsp 813
# kroB200.tsp 814
# kroB200.tsp 815
# kroB200.tsp 816
# kroB200.tsp 817
# kroB200.tsp 818
# kroB200.tsp 819
# kroB200.tsp 820
# kroB200.tsp 821
# kroB200.tsp 822
# kroB200.tsp 823
# kroB200.tsp 824
# kroB200.tsp 825
# kroB200.tsp 826
# kroB200.tsp 827
# kroB200.tsp 828
# kroB200.tsp 829
# kroB200.tsp 830
# kroB200.tsp 831
# kroB200.tsp 832
# kroB200.tsp 833
# kroB200.tsp 834
# kroB200.tsp 835
# kroB200.tsp 836
# kroB200.tsp 837
# kroB200.tsp 838
# kroB200.tsp 839
# kroB200.tsp 840
# kroB200.tsp 841
# kroB200.tsp 842
# kroB200.tsp 843
# kroB200.tsp 844
# kroB200.tsp 845
# kroB200.tsp 846
# kroB200.tsp 847
# kroB200.tsp 848
# kroB200.tsp 849
# kroB200.tsp 850
# kroB200.tsp 851
# kroB200.tsp 852
# kroB200.tsp 853
# kroB200.tsp 854
# kroB200.tsp 855
# kroB200.tsp 856
# kroB200.tsp 857
# kroB200.tsp 858
# kroB200.tsp 859
# kroB200.tsp 860
# kroB200.tsp 861
# kroB200.tsp 862
# kroB200.tsp 863
# kroB200.tsp 864
# kroB200.tsp 865
# kroB200.tsp 866
# kroB200.tsp 867
# kroB200.tsp 868
# kroB200.tsp 869
# kroB200.tsp 870
# kroB200.tsp 871
# kroB200.tsp 872
# kroB200.tsp 873
# kroB200.tsp 874
# kroB200.tsp 875
# kroB200.tsp 876
# kroB200.tsp 877
# kroB200.tsp 878
# kroB200.tsp 879
# kroB200.tsp 880
# kroB200.tsp 881
# kroB200.tsp 882
# kroB200.tsp 883
# kroB200.tsp 884
# kroB200.tsp 885
# kroB200.tsp 886
# kroB200.tsp 887
# kroB200.tsp 888
# kroB200.tsp 889
# kroB200.tsp 890
# kroB200.tsp 891
# kroB200.tsp 892
# kroB200.tsp 893
# kroB200.tsp 894
# kroB200.tsp 895
# kroB200.tsp 896
# kroB200.tsp 897
# kroB200.tsp 898
# kroB200.tsp 899
# kroB200.tsp 900
# kroB200.tsp 901
# kroB200.tsp 902
# kroB200.tsp 903
# kroB200.tsp 904
# kroB200.tsp 905
# kroB200.tsp 906
# kroB200.tsp 907
# kroB200.tsp 908
# kroB200.tsp 909
# kroB200.tsp 910
# kroB200.tsp 911
# kroB200.tsp 912
# kroB200.tsp 913
# kroB200.tsp 914
# kroB200.tsp 915
# kroB200.tsp 916
# kroB200.tsp 917
# kroB200.tsp 918
# kroB200.tsp 919
# kroB200.tsp 920
# kroB200.tsp 921
# kroB200.tsp 922
# kroB200.tsp 923
# kroB200.tsp 924
# kroB200.tsp 925
# kroB200.tsp 926
# kroB200.tsp 927
# kroB200.tsp 928
# kroB200.tsp 929
# kroB200.tsp 930
# kroB200.tsp 931
# kroB200.tsp 932
# kroB200.tsp 933
# kroB200.tsp 934
# kroB200.tsp 935
# kroB200.tsp 936
# kroB200.tsp 937
# kroB200.tsp 938
# kroB200.tsp 939
# kroB200.tsp 940
# kroB200.tsp 941
# kroB200.tsp 942
# kroB200.tsp 943
# kroB200.tsp 944
# kroB200.tsp 945
# kroB200.tsp 946
# kroB200.tsp 947
# kroB200.tsp 948
# kroB200.tsp 949
# kroB200.tsp 950
# kroB200.tsp 951
# kroB200.tsp 952
# kroB200.tsp 953
# kroB200.tsp 954
# kroB200.tsp 955
# kroB200.tsp 956
# kroB200.tsp 957
# kroB200.tsp 958
# kroB200.tsp 959
# kroB200.tsp 960
# kroB200.tsp 961
# kroB200.tsp 962
# kroB200.tsp 963
# kroB200.tsp 964
# kroB200.tsp 965
# kroB200.tsp 966
# kroB200.tsp 967
# kroB200.tsp 968
# kroB200.tsp 969
# kroB200.tsp 970
# kroB200.tsp 971
# kroB200.tsp 972
# kroB200.tsp 973
# kroB200.tsp 974
# kroB200.tsp 975
# kroB200.tsp 976
# kroB200.tsp 977
# kroB200.tsp 978
# kroB200.tsp 979
# kroB200.tsp 980
# kroB200.tsp 981
# kroB200.tsp 982
# kroB200.tsp 983
# kroB200.tsp 984
# kroB200.tsp 985
# kroB200.tsp 986
# kroB200.tsp 987
# kroB200.tsp 988
# kroB200.tsp 989
# kroB200.tsp 990
# kroB200.tsp 991
# kroB200.tsp 992
# kroB200.tsp 993
# kroB200.tsp 994
# kroB200.tsp 995
# kroB200.tsp 996
# kroB200.tsp 997
# kroB200.tsp 998
# kroB200.tsp 999
# start measure
# 35152.0
# kroB200.tsp 551
# kroB200.tsp 552
# kroB200.tsp 553
# kroB200.tsp 554
# kroB200.tsp 555
# kroB200.tsp 556
# kroB200.tsp 557
# kroB200.tsp 558
# kroB200.tsp 559
# kroB200.tsp 560
# kroB200.tsp 561
# kroB200.tsp 562
# kroB200.tsp 563
# kroB200.tsp 564
# kroB200.tsp 565
# kroB200.tsp 566
# kroB200.tsp 567
# kroB200.tsp 568
# kroB200.tsp 569
# kroB200.tsp 570
# kroB200.tsp 571
# kroB200.tsp 572
# kroB200.tsp 573
# kroB200.tsp 574
# kroB200.tsp 575
# kroB200.tsp 576
# kroB200.tsp 577
# kroB200.tsp 578
# kroB200.tsp 579
# kroB200.tsp 580
# kroB200.tsp 581
# kroB200.tsp 582
# kroB200.tsp 583
# kroB200.tsp 584
# kroB200.tsp 585
# kroB200.tsp 586
# kroB200.tsp 587
# kroB200.tsp 588
# kroB200.tsp 589
# kroB200.tsp 590
# kroB200.tsp 591
# kroB200.tsp 592
# kroB200.tsp 593
# kroB200.tsp 594
# kroB200.tsp 595
# kroB200.tsp 596
# kroB200.tsp 597
# kroB200.tsp 598
# kroB200.tsp 599
# kroB200.tsp 600
# kroB200.tsp 601
# kroB200.tsp 602
# kroB200.tsp 603
# kroB200.tsp 604
# kroB200.tsp 605
# kroB200.tsp 606
# kroB200.tsp 607
# kroB200.tsp 608
# kroB200.tsp 609
# kroB200.tsp 610
# kroB200.tsp 611
# kroB200.tsp 612
# kroB200.tsp 613
# kroB200.tsp 614
# kroB200.tsp 615
# kroB200.tsp 616
# kroB200.tsp 617
# kroB200.tsp 618
# kroB200.tsp 619
# kroB200.tsp 620
# kroB200.tsp 621
# kroB200.tsp 622
# kroB200.tsp 623
# kroB200.tsp 624
# kroB200.tsp 625
# kroB200.tsp 626
# kroB200.tsp 627
# kroB200.tsp 628
# kroB200.tsp 629
# kroB200.tsp 630
# kroB200.tsp 631
# kroB200.tsp 632
# kroB200.tsp 633
# kroB200.tsp 634
# kroB200.tsp 635
# kroB200.tsp 636
# kroB200.tsp 637
# kroB200.tsp 638
# kroB200.tsp 639
# kroB200.tsp 640
# kroB200.tsp 641
# kroB200.tsp 642
# kroB200.tsp 643
# kroB200.tsp 644
# kroB200.tsp 645
# kroB200.tsp 646
# kroB200.tsp 647
# kroB200.tsp 648
# kroB200.tsp 649
# kroB200.tsp 650
# kroB200.tsp 651
# kroB200.tsp 652
# kroB200.tsp 653
# kroB200.tsp 654
# kroB200.tsp 655
# kroB200.tsp 656
# kroB200.tsp 657
# kroB200.tsp 658
# kroB200.tsp 659
# kroB200.tsp 660
# kroB200.tsp 661
# kroB200.tsp 662
# kroB200.tsp 663
# kroB200.tsp 664
# kroB200.tsp 665
# kroB200.tsp 666
# kroB200.tsp 667
# kroB200.tsp 668
# kroB200.tsp 669
# kroB200.tsp 670
# kroB200.tsp 671
# kroB200.tsp 672
# kroB200.tsp 673
# kroB200.tsp 674
# kroB200.tsp 675
# kroB200.tsp 676
# kroB200.tsp 677
# kroB200.tsp 678
# kroB200.tsp 679
# kroB200.tsp 680
# kroB200.tsp 681
# kroB200.tsp 682
# kroB200.tsp 683
# kroB200.tsp 684
# kroB200.tsp 685
# kroB200.tsp 686
# kroB200.tsp 687
# kroB200.tsp 688
# kroB200.tsp 689
# kroB200.tsp 690
# kroB200.tsp 691
# kroB200.tsp 692
# kroB200.tsp 693
# kroB200.tsp 694
# kroB200.tsp 695
# kroB200.tsp 696
# kroB200.tsp 697
# kroB200.tsp 698
# kroB200.tsp 699
# kroB200.tsp 700
# kroB200.tsp 701
# kroB200.tsp 702
# kroB200.tsp 703
# kroB200.tsp 704
# kroB200.tsp 705
# kroB200.tsp 706
# kroB200.tsp 707
# kroB200.tsp 708
# kroB200.tsp 709
# kroB200.tsp 710
# kroB200.tsp 711
# kroB200.tsp 712
# kroB200.tsp 713
# kroB200.tsp 714
# kroB200.tsp 715
# kroB200.tsp 716
# kroB200.tsp 717
# kroB200.tsp 718
# kroB200.tsp 719
# kroB200.tsp 720
# kroB200.tsp 721
# kroB200.tsp 722
# kroB200.tsp 723
# kroB200.tsp 724
# kroB200.tsp 725
# kroB200.tsp 726
# kroB200.tsp 727
# kroB200.tsp 728
# kroB200.tsp 729
# kroB200.tsp 730
# kroB200.tsp 731
# kroB200.tsp 732
# kroB200.tsp 733
# kroB200.tsp 734
# kroB200.tsp 735
# kroB200.tsp 736
# kroB200.tsp 737
# kroB200.tsp 738
# kroB200.tsp 739
# kroB200.tsp 740
# kroB200.tsp 741
# kroB200.tsp 742
# kroB200.tsp 743
# kroB200.tsp 744
# kroB200.tsp 745
# kroB200.tsp 746
# kroB200.tsp 747
# kroB200.tsp 748
# kroB200.tsp 749
# kroB200.tsp 750
# kroB200.tsp 751
# kroB200.tsp 752
# kroB200.tsp 753
# kroB200.tsp 754
# kroB200.tsp 755
# kroB200.tsp 756
# kroB200.tsp 757
# kroB200.tsp 758
# kroB200.tsp 759
# kroB200.tsp 760
# kroB200.tsp 761
# kroB200.tsp 762
# kroB200.tsp 763
# kroB200.tsp 764
# kroB200.tsp 765
# kroB200.tsp 766
# kroB200.tsp 767
# kroB200.tsp 768
# kroB200.tsp 769
# kroB200.tsp 770
# kroB200.tsp 771
# kroB200.tsp 772
# kroB200.tsp 773
# kroB200.tsp 774
# kroB200.tsp 775
# kroB200.tsp 776
# kroB200.tsp 777
# kroB200.tsp 778
# kroB200.tsp 779
# kroB200.tsp 780
# kroB200.tsp 781
# kroB200.tsp 782
# kroB200.tsp 783
# kroB200.tsp 784
# kroB200.tsp 785
# kroB200.tsp 786
# kroB200.tsp 787
# kroB200.tsp 788
# kroB200.tsp 789
# kroB200.tsp 790
# kroB200.tsp 791
# kroB200.tsp 792
# kroB200.tsp 793
# kroB200.tsp 794
# kroB200.tsp 795
# kroB200.tsp 796
# kroB200.tsp 797
# kroB200.tsp 798
# kroB200.tsp 799
# kroB200.tsp 800
# kroB200.tsp 801
# kroB200.tsp 802
# kroB200.tsp 803
# kroB200.tsp 804
# kroB200.tsp 805
# kroB200.tsp 806
# kroB200.tsp 807
# kroB200.tsp 808
# kroB200.tsp 809
# kroB200.tsp 810
# kroB200.tsp 811
# kroB200.tsp 812
# kroB200.tsp 813
# kroB200.tsp 814
# kroB200.tsp 815
# kroB200.tsp 816
# kroB200.tsp 817
# kroB200.tsp 818
# kroB200.tsp 819
# kroB200.tsp 820
# kroB200.tsp 821
# kroB200.tsp 822
# kroB200.tsp 823
# kroB200.tsp 824
# kroB200.tsp 825
# kroB200.tsp 826
# kroB200.tsp 827
# kroB200.tsp 828
# kroB200.tsp 829
# kroB200.tsp 830
# kroB200.tsp 831
# kroB200.tsp 832
# kroB200.tsp 833
# kroB200.tsp 834
# kroB200.tsp 835
# kroB200.tsp 836
# kroB200.tsp 837
# kroB200.tsp 838
# kroB200.tsp 839
# kroB200.tsp 840
# kroB200.tsp 841
# kroB200.tsp 842
# kroB200.tsp 843
# kroB200.tsp 844
# kroB200.tsp 845
# kroB200.tsp 846
# kroB200.tsp 847
# kroB200.tsp 848
# kroB200.tsp 849
# kroB200.tsp 850
# kroB200.tsp 851
# kroB200.tsp 852
# kroB200.tsp 853
# kroB200.tsp 854
# kroB200.tsp 855
# kroB200.tsp 856
# kroB200.tsp 857
# kroB200.tsp 858
# kroB200.tsp 859
# kroB200.tsp 860
# kroB200.tsp 861
# kroB200.tsp 862
# kroB200.tsp 863
# kroB200.tsp 864
# kroB200.tsp 865
# kroB200.tsp 866
# kroB200.tsp 867
# kroB200.tsp 868
# kroB200.tsp 869
# kroB200.tsp 870
# kroB200.tsp 871
# kroB200.tsp 872
# kroB200.tsp 873
# kroB200.tsp 874
# kroB200.tsp 875
# kroB200.tsp 876
# kroB200.tsp 877
# kroB200.tsp 878
# kroB200.tsp 879
# kroB200.tsp 880
# kroB200.tsp 881
# kroB200.tsp 882
# kroB200.tsp 883
# kroB200.tsp 884
# kroB200.tsp 885
# kroB200.tsp 886
# kroB200.tsp 887
# kroB200.tsp 888
# kroB200.tsp 889
# kroB200.tsp 890
# kroB200.tsp 891
# kroB200.tsp 892
# kroB200.tsp 893
# kroB200.tsp 894
# kroB200.tsp 895
# kroB200.tsp 896
# kroB200.tsp 897
# kroB200.tsp 898
# kroB200.tsp 899
# kroB200.tsp 900
# kroB200.tsp 901
# kroB200.tsp 902
# kroB200.tsp 903
# kroB200.tsp 904
# kroB200.tsp 905
# kroB200.tsp 906
# kroB200.tsp 907
# kroB200.tsp 908
# kroB200.tsp 909
# kroB200.tsp 910
# kroB200.tsp 911
# kroB200.tsp 912
# kroB200.tsp 913
# kroB200.tsp 914
# kroB200.tsp 915
# kroB200.tsp 916
# kroB200.tsp 917
# kroB200.tsp 918
# kroB200.tsp 919
# kroB200.tsp 920
# kroB200.tsp 921
# kroB200.tsp 922
# kroB200.tsp 923
# kroB200.tsp 924
# kroB200.tsp 925
# kroB200.tsp 926
# kroB200.tsp 927
# kroB200.tsp 928
# kroB200.tsp 929
# kroB200.tsp 930
# kroB200.tsp 931
# kroB200.tsp 932
# kroB200.tsp 933
# kroB200.tsp 934
# kroB200.tsp 935
# kroB200.tsp 936
# kroB200.tsp 937
# kroB200.tsp 938
# kroB200.tsp 939
# kroB200.tsp 940
# kroB200.tsp 941
# kroB200.tsp 942
# kroB200.tsp 943
# kroB200.tsp 944
# kroB200.tsp 945
# kroB200.tsp 946
# kroB200.tsp 947
# kroB200.tsp 948
# kroB200.tsp 949
# kroB200.tsp 950
# kroB200.tsp 951
# kroB200.tsp 952
# kroB200.tsp 953
# kroB200.tsp 954
# kroB200.tsp 955
# kroB200.tsp 956
# kroB200.tsp 957
# kroB200.tsp 958
# kroB200.tsp 959
# kroB200.tsp 960
# kroB200.tsp 961
# kroB200.tsp 962
# kroB200.tsp 963
# kroB200.tsp 964
# kroB200.tsp 965
# kroB200.tsp 966
# kroB200.tsp 967
# kroB200.tsp 968
# kroB200.tsp 969
# kroB200.tsp 970
# kroB200.tsp 971
# kroB200.tsp 972
# kroB200.tsp 973
# kroB200.tsp 974
# kroB200.tsp 975
# kroB200.tsp 976
# kroB200.tsp 977
# kroB200.tsp 978
# kroB200.tsp 979
# kroB200.tsp 980
# kroB200.tsp 981
# kroB200.tsp 982
# kroB200.tsp 983
# kroB200.tsp 984
# kroB200.tsp 985
# kroB200.tsp 986
# kroB200.tsp 987
# kroB200.tsp 988
# kroB200.tsp 989
# kroB200.tsp 990
# kroB200.tsp 991
# kroB200.tsp 992
# kroB200.tsp 993
# kroB200.tsp 994
# kroB200.tsp 995
# kroB200.tsp 996
# kroB200.tsp 997
# kroB200.tsp 998
# kroB200.tsp 999
# start measure
# 34654.0

# %%
plt.plot(best_score_arr, first_scores_arr, ".")
plt.xlabel("lenght")
plt.ylabel("score")
plt.show()

# %%
plt.plot(best_score_arr, second_scores_arr, ".")
plt.xlabel("lenght")
plt.ylabel("score")
plt.show()

# %%
plt.plot(best_score_arr, avg_first_scores_arr, ".")
plt.xlabel("lenght")
plt.ylabel("score")
plt.show()

# %%
plt.plot(best_score_arr, avg_second_scores_arr, ".")
plt.xlabel("lenght")
plt.ylabel("score")
plt.show()

# %%
korelacja = np.corrcoef(best_score_arr, first_scores_arr)[0, 1]
print("Współczynnik korelacji Pearsona:", korelacja)
korelacja = np.corrcoef(best_score_arr, second_scores_arr)[0, 1]
print("Współczynnik korelacji Pearsona:", korelacja)
korelacja = np.corrcoef(best_score_arr, avg_first_scores_arr)[0, 1]
print("Współczynnik korelacji Pearsona:", korelacja)
korelacja = np.corrcoef(best_score_arr, avg_second_scores_arr)[0, 1]
print("Współczynnik korelacji Pearsona:", korelacja)
# Out:
# Współczynnik korelacji Pearsona: -0.1038605168676581
# Współczynnik korelacji Pearsona: -0.2878801835720974
# Współczynnik korelacji Pearsona: 0.10386051686765625
# Współczynnik korelacji Pearsona: 0.2878801835721195

# %%
def show_results1000():
    instances = ['kroB200.tsp']
    initial_solvers = [solve_random]
    score_results = []
    time_results = []
    best_score_arr = []
    first_scores_arr = []
    second_scores_arr = []
    avg_first_scores_arr = []
    avg_second_scores_arr = []
    all_solutions = []
    all_scores = []
    best_score = 100000000000000
    for file in instances:
        cities, coords = read_instance(file)
        local_variants = [GreedySearch(cities, "edges")]
        for solve in initial_solvers:
            times, new_solutions = [], []
            for i in range(500):
                new_solutions = []
                for local_search in local_variants:
                    solution = solve((cities, i))
                    print(file, i)
                    time, new_solution = local_search(solution)
                    times.append(time)
                    new_solutions.append(new_solution)
                    all_solutions.append(new_solution)                   
                    new_scores = [score(cities, x) for x in new_solutions]
                    all_scores.append(new_scores[0])
                    for j in range(0, len(new_scores)):
                        if new_scores[j] < best_score:
                            best_score = new_scores[j]
                            best_idx = j
                            best = new_solutions[j]
    print("start measure")
    for i in range(len(all_solutions)):
        if all_solutions[i] == best:
            continue
        first_avg = 0
        second_avg = 0
        for j, opt_for_avg in enumerate(all_solutions):
            if i == j or opt_for_avg == best:
                continue
            first_avg += count_first_score(opt_for_avg, all_solutions[i])
            second_avg += count_second_score(opt_for_avg, all_solutions[i])
        avg_first_scores_arr.append(first_avg / float(len(all_solutions) - 2))
        avg_second_scores_arr.append(second_avg / float(len(all_solutions) - 2))
        best_score_arr.append(all_scores[i])
        first_scores_arr.append(count_first_score(all_solutions[i], best))
        second_scores_arr.append(count_second_score(all_solutions[i], best))
    
    # Compute correlation coefficients
    corr_first = np.corrcoef(best_score_arr, avg_first_scores_arr)[0, 1]
    corr_second = np.corrcoef(best_score_arr, avg_second_scores_arr)[0, 1]

    # Plotting the results
    import matplotlib.pyplot as plt

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.scatter(best_score_arr, avg_first_scores_arr)
    plt.title('Objective Value vs Average First Similarity')
    plt.xlabel('Objective Value')
    plt.ylabel('Average First Similarity')

    plt.subplot(1, 2, 2)
    plt.scatter(best_score_arr, avg_second_scores_arr)
    plt.title('Objective Value vs Average Second Similarity')
    plt.xlabel('Objective Value')
    plt.ylabel('Average Second Similarity')

    plt.tight_layout()
    plt.show()

    print(f"Correlation coefficient (First Similarity): {corr_first}")
    print(f"Correlation coefficient (Second Similarity): {corr_second}")

    return best_score, best_score_arr, first_scores_arr, second_scores_arr, avg_first_scores_arr, avg_second_scores_arr

# %%
best_score_arr = []
first_scores_arr = []
second_scores_arr = []
avg_first_scores_arr = []
avg_second_scores_arr = []
best_score, best_score_arr, first_scores_arr, second_scores_arr, avg_first_scores_arr, avg_second_scores_arr = show_results1000()
print(best_score)
# Out:
# kroB200.tsp 0
# kroB200.tsp 1
# kroB200.tsp 2
# kroB200.tsp 3
# kroB200.tsp 4
# kroB200.tsp 5
# kroB200.tsp 6
# kroB200.tsp 7
# kroB200.tsp 8
# kroB200.tsp 9
# kroB200.tsp 10
# kroB200.tsp 11
# kroB200.tsp 12
# kroB200.tsp 13
# kroB200.tsp 14
# kroB200.tsp 15
# kroB200.tsp 16
# kroB200.tsp 17
# kroB200.tsp 18
# kroB200.tsp 19
# kroB200.tsp 20
# kroB200.tsp 21
# kroB200.tsp 22
# kroB200.tsp 23
# kroB200.tsp 24
# kroB200.tsp 25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 6
#       4 avg_first_scores_arr = []
#       5 avg_second_scores_arr = []
# ----> 6 best_score, best_score_arr, first_scores_arr, second_scores_arr, avg_first_scores_arr, avg_second_scores_arr = show_results1000()
#       7 print(best_score)
#
# Cell In[21], line 24, in show_results1000()
#      22 solution = solve((cities, i))
#      23 print(file, i)
# ---> 24 time, new_solution = local_search(solution)
#      25 times.append(time)
#      26 new_solutions.append(new_solution)
#
# Cell In[7], line 43, in GreedySearch.__call__(self, paths)
#      41 while True:
#      42     move_order = random.sample(range(2), 2)
# ---> 43     score = self.moves[move_order[0]](self.cities, paths)
#      44     if score >= 0:
#      45         score = self.moves[move_order[1]](self.cities, paths)
#
# Cell In[7], line 16, in GreedySearch.outside_vertices_trade_first(self, cities, paths)
#      14 random.seed()
#      15 candidates = outside_candidates(paths)
# ---> 16 random.shuffle(candidates)
#      17 for i, j in candidates:
#      18     score_diff = delta_replace_vertices_outside(cities, paths, i, j)
#
# File ~\anaconda3\Lib\random.py:383, in Random.shuffle(self, x)
#     380 for i in reversed(range(1, len(x))):
#     381     # pick an element in x[:i+1] with which to exchange x[i]
#     382     j = randbelow(i + 1)
# --> 383     x[i], x[j] = x[j], x[i]
#
# KeyboardInterrupt:
